# %%
train_filename = 'snli_1.0_dev_filtered.jsonl'
test_filename = 'snli_1.0_dev_gold_labels.csv'
data_path = '../eci2019nlp/'

# %%
import pandas as pd

# %%
train_df = pd.read_json(data_path + train_filename, lines=True)
train_df
# Out:
#                                               sentence2         captionID  \
# 0     The sisters are hugging goodbye while holding ...  4705552913.jpg#2
# 1                       Two woman are holding packages.  4705552913.jpg#2
# 2                  The men are fighting outside a deli.  4705552913.jpg#2
# 3        Two kids in numbered jerseys wash their hands.  2407214681.jpg#0
# 4              Two kids at a ballgame wash their hands.  2407214681.jpg#0
# ...                                                 ...               ...
# 9837                            The carousel is moving.    77063034.jpg#3
# 9838          The girl is moving at the speed of light.    77063034.jpg#3
# 9839                         People in a water fountain  4805835848.jpg#0
# 9840                       A young girl knits a sweater  4805835848.jpg#0
# 9841  A young mother tries to grab her topless child...  4805835848.jpg#0
#
#                    pairID                             sentence2_binary_parse  \
# ...

# %%
train_df.iloc[0]['sentence2']
# Out:
# 'The sisters are hugging goodbye while holding to go packages after just eating lunch.'

# %%
train_df.iloc[0]['sentence2_parse']
# Out:
# '(ROOT (S (NP (DT The) (NNS sisters)) (VP (VBP are) (VP (VBG hugging) (NP (UH goodbye)) (PP (IN while) (S (VP (VBG holding) (S (VP (TO to) (VP (VB go) (NP (NNS packages)) (PP (IN after) (S (ADVP (RB just)) (VP (VBG eating) (NP (NN lunch))))))))))))) (. .)))'

# %%
train_df.iloc[0]['sentence2_binary_parse']
# Out:
# '( ( The sisters ) ( ( are ( ( hugging goodbye ) ( while ( holding ( to ( ( go packages ) ( after ( just ( eating lunch ) ) ) ) ) ) ) ) ) . ) )'

# %%
pd.read_csv(data_path + test_filename)
# Out:
#                    pairID     gold_label
# 0     4705552913.jpg#2r1n        neutral
# 1     4705552913.jpg#2r1e     entailment
# 2     4705552913.jpg#2r1c  contradiction
# 3     2407214681.jpg#0r1e     entailment
# 4     2407214681.jpg#0r1n        neutral
# ...                   ...            ...
# 9837    77063034.jpg#3r1e     entailment
# 9838    77063034.jpg#3r1c  contradiction
# 9839  4805835848.jpg#0r1e     entailment
# 9840  4805835848.jpg#0r1c  contradiction
# 9841  4805835848.jpg#0r1n        neutral
#
# [9842 rows x 2 columns]
